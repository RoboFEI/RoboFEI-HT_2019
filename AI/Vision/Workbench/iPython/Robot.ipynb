# %% [markdown]
# ****************************************************************************
# * @file: Robot.py
# * @project: ROBOFEI-HT - FEI 😛
# * @author: Vinicius Nicassio Ferreira
# * @version: V0.0.1
# * @created: 23/10/2017
# * @e-mail: vinicius.nicassio@gmail.com
# * @brief: Class Robot
# ****************************************************************************

# %%
#ini-iPython

# %% [markdown]
# # Executando no diretório principal

# %%
import os
os.chdir('../../') #Executando no diretório principal
os.system("cd Workbench/ && ./zerar.sh && cd ..")
os.system("cd Workbench/iPython/ && ./convertendo.sh && cd ../../")
import sys
sys.path.append('./include')
sys.path.append('./src')
sys.path.append('./Workbench/iPython')
#end-iPython

# %% [markdown]
# ---- Imports ----

# %%
# The standard libraries used in the vision system.

# %%
# The standard libraries used in the visual memory system.
import cv2 # OpenCV library used for image processing.

# %%
# Used class developed by RoboFEI-HT.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#ini-iPython - Utilizado para o iPython reconhecer as classes
sys.path.append('/home/vinicius/models/research')
sys.path.append('/home/vinicius/models/research/object_detection')
#end-iPython
from DNN import *

def plot(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.grid()
    plt.show()

# %%
image = cv2.imread("/home/vinicius/Dropbox/Projeto Mestrado/Codigos/RoboFEI-HT_Debug/AI/Vision/Workbench/iPython/Competicao.jpg")
plot(image)

# %%
class argumentos:
    camera = False
    dnn = False
    train = False

a = argumentos()

classific = DNN(a)
# Out:
# DNN - PARAMETERS section not found!

# %%
observation = {}
observation['frame'] = image.copy()

observation['objetos'] = classific.detect(observation)
observation['objetos'] = observation['objetos'][observation['objetos'].classes != "robot"].reset_index()
del observation['objetos']["index"]
observation['objetos']
# Out:
#         classes    scores                                              boxes
# 0             T  0.997998  [0.21505959332, 0.0655504018068, 0.26397007703...
# 1             L  0.995902  [0.374392569065, 0.74590241909, 0.420733869076...
# 2             L  0.975340  [0.818051993847, 0.440327614546, 0.92762988805...
# 3             T  0.866779  [0.908592939377, 0.760798692703, 0.99171841144...
# 4  penalty_mark  0.794615  [0.463073551655, 0.2639092803, 0.495803654194,...

# %%
frame = image.copy()
for __, __, pos in observation['objetos'].values[:1]:
    cv2.circle(
        frame,
        tuple(
            np.resize(
                np.array(pos)*np.array(frame.shape[:2]+frame.shape[:2]),
                (2,2)
            ).mean(axis=0).astype(int)
        )[::-1],
        20,
        (255, 0, 255),
        -1,
    )
plot(frame)

# %%
for i in xrange(len(observation['objetos'])):
    observation['objetos']["boxes"][i] = np.resize(
        np.array(observation['objetos'].loc[i, "boxes"])*np.array(image.shape[:2]+image.shape[:2]),
        (2,2)
    ).mean(axis=0).astype(int).tolist()
observation['objetos']
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#         classes    scores        boxes
# 0             T  0.997998   [172, 108]
# 1             L  0.995902   [286, 984]
# 2             L  0.975340   [628, 609]
# 3             T  0.866779  [684, 1024]
# 4  penalty_mark  0.794615   [345, 370]

# %% [markdown]
# # Class Robot
# .
# doxygen-iPython

# %%
#des-iPython class Robot( ):
#ini-tab -> Iniciando código classe

# %% [markdown]
# ---- Variables ----

# %%
#ini-iPython

# ------- Lista de funções -------



#end-iPython - Fim listas

# %% [markdown]
# # Constructor Class
# doxygen-iPython

# %%
#des-iPython def __init__(self):
#ini-tab -> Criando construtor
pass

# %%
#end-tab -> Finalizando construtor

# %%
#ini-iPython

# %% [markdown]
# ## Teste construtor

# %%
#end-iPython

# %%
#end-tab -> Finalizando classe

# %%
#ini-iPython

# %% [markdown]
# # nova_variavel
# .
# doxygen-iPython

# %%
nova_variavel = None #self-iPython nova_variavel

# %% [markdown]
# # nova_funcao
# .
# doxygen-iPython

# %%
# eself-iPython nova_funcao
# edes-iPython def nova_funcao(self, variaveis_funcao):
def nova_funcao(variaveis_funcao):
    pass # self-iPython nova_funcao

# %%
#ini-iPython

# %% [markdown]
# ## Teste nova_funcao

# %%
#end-iPython

# %%
#end-iPython
