# %%
import pandas as pd
import numpy as np

# %%
observacao = pd.DataFrame([
    ["L", 0.98, [3./4, 1./3]],
    ["base_gol", 0.98, [4./4, 2./3]],
    ["penalt_mark", 0.98, [2./4, 3./3]],
], columns = [
        "classes",
        "scores",
        "boxes",
    ]
)
observacao
# Out:
#        classes  scores                   boxes
# 0            L    0.98  [0.75, 0.333333333333]
# 1     base_gol    0.98   [1.0, 0.666666666667]
# 2  penalt_mark    0.98              [0.5, 1.0]

# %%
# Landmark corner
lista = []
num = 1
pos = [
    [10.4, 0],
    [10.4, 7.4],
    [0, 7.4],
    [0, 0],
]
for horizonte in ["frente", "atrás"]:
    for vertical in ["esq", "dir"]:
        lista.append(["corner"+str(num), pos.pop(0), "corner", horizonte, vertical, 1.0/4])
        num += 1

# Landmark L
num = 1
pos = [
    [9.7, 0.7],
    [8.7, 1.2],
    [8.7, 6.2],
    [9.7, 6.7],
    [1.7, 1.2],
    [0.7, 0.7],
    [0.7, 6.7],
    [1.7, 6.2],
]
for horizonte in ["frente", "atrás"]:
    for vertical in ["esq", "dir"]:
        for __ in xrange(2):
            lista.append(["L"+str(num), pos.pop(0), "L", horizonte, vertical, 1.0/8])
            num += 1

# Landmark base_gol
num = 1
pos = [
    [9.7, 2.4],
    [9.7, 5.0],
    [0.7, 2.4],
    [0.7, 5.0],
]
for horizonte in ["frente", "atrás"]:
    for vertical in ["esq", "dir"]:
        lista.append(["base_gol"+str(num), pos.pop(0), "base_gol", horizonte, vertical, 1.0/4])
        num += 1

# Landmark T
num = 1
pos = [
    [9.7, 1.2],
    [9.7, 6.2],
    [5.2, 0.7],
    [5.2, 6.7],
    [0.7, 1.2],
    [0.7, 6.2],
]
for horizonte in ["frente", "meio", "atrás"]:
    for vertical in ["esq", "dir"]:
        lista.append(["T"+str(num), pos.pop(0), "T", horizonte, vertical, 1.0/6])
        num += 1

# Landmark X
num = 1
pos = [
    [5.2, 2.95],
    [5.2, 4.45],
]
for vertical in ["esq", "dir"]:
    lista.append(["X"+str(num), pos.pop(0), "X", "meio", vertical, 1.0/2])
    num += 1

# Landmark penalt_mark
num = 1
pos = [
    [7.6, 10.4],
    [2.8, 10.4],
]
for horizonte in ["frente", "atrás"]:
    lista.append(["penalt_mark"+str(num), pos.pop(0), "penalt_mark", horizonte, "meio", 1.0/2])
    num += 1

lista.append(["centro", [5.2, 3.7], "centro", "meio", "meio", 1.0/2])
lista = pd.DataFrame(lista, columns = ["tag", "pos", "classes", "vertical", "horizontal", "propabilidade"])
lista
# Out:
#              tag          pos      classes vertical horizontal  propabilidade
# 0        corner1    [10.4, 0]       corner   frente        esq       0.250000
# 1        corner2  [10.4, 7.4]       corner   frente        dir       0.250000
# 2        corner3     [0, 7.4]       corner    atrás        esq       0.250000
# 3        corner4       [0, 0]       corner    atrás        dir       0.250000
# 4             L1   [9.7, 0.7]            L   frente        esq       0.125000
# 5             L2   [8.7, 1.2]            L   frente        esq       0.125000
# 6             L3   [8.7, 6.2]            L   frente        dir       0.125000
# 7             L4   [9.7, 6.7]            L   frente        dir       0.125000
# 8             L5   [1.7, 1.2]            L    atrás        esq       0.125000
# 9             L6   [0.7, 0.7]            L    atrás        esq       0.125000
# 10            L7   [0.7, 6.7]            L    atrás        dir       0.125000
# 11            L8   [1.7, 6.2]            L    atrás        dir       0.125000
# 12     base_gol1   [9.7, 2.4]     base_gol   frente        esq       0.250000
# 13     base_gol2   [9.7, 5.0]     base_gol   frente        dir       0.250000
# 14     base_gol3   [0.7, 2.4]     base_gol    atrás        esq       0.250000
# 15     base_gol4   [0.7, 5.0]     base_gol    atrás        dir       0.250000
# 16            T1   [9.7, 1.2]            T   frente        esq       0.166667
# 17            T2   [9.7, 6.2]            T   frente        dir       0.166667
# 18            T3   [5.2, 0.7]            T     meio        esq       0.166667
# 19            T4   [5.2, 6.7]            T     meio        dir       0.166667
# 20            T5   [0.7, 1.2]            T    atrás        esq       0.166667
# 21            T6   [0.7, 6.2]            T    atrás        dir       0.166667
# 22            X1  [5.2, 2.95]            X     meio        esq       0.500000
# 23            X2  [5.2, 4.45]            X     meio        dir       0.500000
# 24  penalt_mark1  [7.6, 10.4]  penalt_mark   frente       meio       0.500000
# 25  penalt_mark2  [2.8, 10.4]  penalt_mark    atrás       meio       0.500000
# 26        centro   [5.2, 3.7]       centro     meio       meio       0.500000

# %%
lista.loc[lista.vertical == "frente","propabilidade"] *= 1.1
lista.loc[lista.vertical == "atrás","propabilidade"] *= 0.9

# %%
# lista.loc[lista.horizontal == "esq","propabilidade"] *= 1.1
# lista.loc[lista.horizontal == "dir","propabilidade"] *= 0.9

# %%
lista
# Out:
#              tag          pos      classes vertical horizontal  propabilidade
# 0        corner1    [10.4, 0]       corner   frente        esq       0.275000
# 1        corner2  [10.4, 7.4]       corner   frente        dir       0.275000
# 2        corner3     [0, 7.4]       corner    atrás        esq       0.225000
# 3        corner4       [0, 0]       corner    atrás        dir       0.225000
# 4             L1   [9.7, 0.7]            L   frente        esq       0.137500
# 5             L2   [8.7, 1.2]            L   frente        esq       0.137500
# 6             L3   [8.7, 6.2]            L   frente        dir       0.137500
# 7             L4   [9.7, 6.7]            L   frente        dir       0.137500
# 8             L5   [1.7, 1.2]            L    atrás        esq       0.112500
# 9             L6   [0.7, 0.7]            L    atrás        esq       0.112500
# 10            L7   [0.7, 6.7]            L    atrás        dir       0.112500
# 11            L8   [1.7, 6.2]            L    atrás        dir       0.112500
# 12     base_gol1   [9.7, 2.4]     base_gol   frente        esq       0.275000
# 13     base_gol2   [9.7, 5.0]     base_gol   frente        dir       0.275000
# 14     base_gol3   [0.7, 2.4]     base_gol    atrás        esq       0.225000
# 15     base_gol4   [0.7, 5.0]     base_gol    atrás        dir       0.225000
# 16            T1   [9.7, 1.2]            T   frente        esq       0.183333
# 17            T2   [9.7, 6.2]            T   frente        dir       0.183333
# 18            T3   [5.2, 0.7]            T     meio        esq       0.166667
# 19            T4   [5.2, 6.7]            T     meio        dir       0.166667
# 20            T5   [0.7, 1.2]            T    atrás        esq       0.150000
# 21            T6   [0.7, 6.2]            T    atrás        dir       0.150000
# 22            X1  [5.2, 2.95]            X     meio        esq       0.500000
# 23            X2  [5.2, 4.45]            X     meio        dir       0.500000
# 24  penalt_mark1  [7.6, 10.4]  penalt_mark   frente       meio       0.550000
# 25  penalt_mark2  [2.8, 10.4]  penalt_mark    atrás       meio       0.450000
# 26        centro   [5.2, 3.7]       centro     meio       meio       0.500000

# %%
condition = 0
for i, __, __ in observacao.drop_duplicates(["classes"]).values:
    condition |= lista.classes == i
lista = lista[condition]
lista = lista.reset_index()
lista
# Out:
#     index           tag          pos      classes vertical horizontal  \
# 0       4            L1   [9.7, 0.7]            L   frente        esq
# 1       5            L2   [8.7, 1.2]            L   frente        esq
# 2       6            L3   [8.7, 6.2]            L   frente        dir
# 3       7            L4   [9.7, 6.7]            L   frente        dir
# 4       8            L5   [1.7, 1.2]            L    atrás        esq
# 5       9            L6   [0.7, 0.7]            L    atrás        esq
# 6      10            L7   [0.7, 6.7]            L    atrás        dir
# 7      11            L8   [1.7, 6.2]            L    atrás        dir
# 8      12     base_gol1   [9.7, 2.4]     base_gol   frente        esq
# 9      13     base_gol2   [9.7, 5.0]     base_gol   frente        dir
# 10     14     base_gol3   [0.7, 2.4]     base_gol    atrás        esq
# 11     15     base_gol4   [0.7, 5.0]     base_gol    atrás        dir
# 12     24  penalt_mark1  [7.6, 10.4]  penalt_mark   frente       meio
# 13     25  penalt_mark2  [2.8, 10.4]  penalt_mark    atrás       meio
#
#     propabilidade
# 0          0.1375
# 1          0.1375
# 2          0.1375
# 3          0.1375
# 4          0.1125
# 5          0.1125
# 6          0.1125
# 7          0.1125
# 8          0.2750
# 9          0.2750
# 10         0.2250
# 11         0.2250
# 12         0.5500
# 13         0.4500

# %%
x = 0
y = 1

for i in xrange(len(observacao)-1):
    for j in xrange(i+1,len(observacao)):
        print "Dado:"
        print observacao.classes[i], "-",observacao.classes[j], ":",
        print observacao.boxes[i][0] - observacao.boxes[j][0], ",", 
        print observacao.boxes[i][1] - observacao.boxes[j][1]
        print "Teste:"
        for k in xrange(len(lista)-1):
            for l in xrange(k+1,len(lista)):
                if observacao.classes[i] == lista.classes[k] and observacao.classes[j] == lista.classes[l]:
                    print lista.classes[k], "-",lista.classes[l], ":",
                    print lista.pos[k][0] - lista.pos[l][0], ",", 
                    print lista.pos[k][1] - lista.pos[l][1]
                    if (observacao.boxes[i][0] - observacao.boxes[j][0]) * (lista.pos[k][0] - lista.pos[l][0]) >= 0 and (observacao.boxes[i][1] - observacao.boxes[j][1]) * (lista.pos[k][1] - lista.pos[l][1]) >= 0:
                        print "Aumentou"
                        lista.loc[k, "propabilidade"] *= 1.3
                        lista.loc[l, "propabilidade"] *= 1.3
                    else:
                        print "Abaixou"
                        lista.loc[k, "propabilidade"] *= 0.7
                        lista.loc[l, "propabilidade"] *= 0.7
                        
        print "\n"
lista
# Out:
# Dado:
# L - base_gol : -0.25 , -0.333333333333
# Teste:
# L - base_gol : 0.0 , -1.7
# Aumentou
# L - base_gol : 0.0 , -4.3
# Aumentou
# L - base_gol : 9.0 , -1.7
# Abaixou
# L - base_gol : 9.0 , -4.3
# Abaixou
# L - base_gol : -1.0 , -1.2
# Aumentou
# L - base_gol : -1.0 , -3.8
# Aumentou
# L - base_gol : 8.0 , -1.2
# Abaixou
# L - base_gol : 8.0 , -3.8
# Abaixou
# L - base_gol : -1.0 , 3.8
# Abaixou
# L - base_gol : -1.0 , 1.2
# Abaixou
# L - base_gol : 8.0 , 3.8
# Abaixou
# L - base_gol : 8.0 , 1.2
# Abaixou
# L - base_gol : 0.0 , 4.3
# Abaixou
# L - base_gol : 0.0 , 1.7
# Abaixou
# L - base_gol : 9.0 , 4.3
# Abaixou
# L - base_gol : 9.0 , 1.7
# Abaixou
# L - base_gol : -8.0 , -1.2
# Aumentou
# L - base_gol : -8.0 , -3.8
# Aumentou
# L - base_gol : 1.0 , -1.2
# Abaixou
# L - base_gol : 1.0 , -3.8
# Abaixou
# L - base_gol : -9.0 , -1.7
# Aumentou
# L - base_gol : -9.0 , -4.3
# Aumentou
# L - base_gol : 0.0 , -1.7
# Aumentou
# L - base_gol : 0.0 , -4.3
# Aumentou
# L - base_gol : -9.0 , 4.3
# Abaixou
# L - base_gol : -9.0 , 1.7
# Abaixou
# L - base_gol : 0.0 , 4.3
# Abaixou
# L - base_gol : 0.0 , 1.7
# Abaixou
# L - base_gol : -8.0 , 3.8
# Abaixou
# L - base_gol : -8.0 , 1.2
# Abaixou
# L - base_gol : 1.0 , 3.8
# Abaixou
# L - base_gol : 1.0 , 1.2
# Abaixou
#
#
# Dado:
# L - penalt_mark : 0.25 , -0.666666666667
# Teste:
# L - penalt_mark : 2.1 , -9.7
# Aumentou
# L - penalt_mark : 6.9 , -9.7
# Aumentou
# L - penalt_mark : 1.1 , -9.2
# Aumentou
# L - penalt_mark : 5.9 , -9.2
# Aumentou
# L - penalt_mark : 1.1 , -4.2
# Aumentou
# L - penalt_mark : 5.9 , -4.2
# Aumentou
# L - penalt_mark : 2.1 , -3.7
# Aumentou
# L - penalt_mark : 6.9 , -3.7
# Aumentou
# L - penalt_mark : -5.9 , -9.2
# Abaixou
# L - penalt_mark : -1.1 , -9.2
# Abaixou
# L - penalt_mark : -6.9 , -9.7
# Abaixou
# L - penalt_mark : -2.1 , -9.7
# Abaixou
# L - penalt_mark : -6.9 , -3.7
# Abaixou
# L - penalt_mark : -2.1 , -3.7
# Abaixou
# L - penalt_mark : -5.9 , -4.2
# Abaixou
# L - penalt_mark : -1.1 , -4.2
# Abaixou
#
#
# Dado:
# base_gol - penalt_mark : 0.5 , -0.333333333333
# Teste:
# base_gol - penalt_mark : 2.1 , -8.0
# Aumentou
# base_gol - penalt_mark : 6.9 , -8.0
# Aumentou
# base_gol - penalt_mark : 2.1 , -5.4
# Aumentou
# base_gol - penalt_mark : 6.9 , -5.4
# Aumentou
# base_gol - penalt_mark : -6.9 , -8.0
# Abaixou
# base_gol - penalt_mark : -2.1 , -8.0
# Abaixou
# base_gol - penalt_mark : -6.9 , -5.4
# Abaixou
# base_gol - penalt_mark : -2.1 , -5.4
# Abaixou
#     index           tag          pos      classes vertical horizontal  \
# 0       4            L1   [9.7, 0.7]            L   frente        esq
# 1       5            L2   [8.7, 1.2]            L   frente        esq
# 2       6            L3   [8.7, 6.2]            L   frente        dir
# 3       7            L4   [9.7, 6.7]            L   frente        dir
# 4       8            L5   [1.7, 1.2]            L    atrás        esq
# 5       9            L6   [0.7, 0.7]            L    atrás        esq
# 6      10            L7   [0.7, 6.7]            L    atrás        dir
# 7      11            L8   [1.7, 6.2]            L    atrás        dir
# 8      12     base_gol1   [9.7, 2.4]     base_gol   frente        esq
# 9      13     base_gol2   [9.7, 5.0]     base_gol   frente        dir
# 10     14     base_gol3   [0.7, 2.4]     base_gol    atrás        esq
# 11     15     base_gol4   [0.7, 5.0]     base_gol    atrás        dir
# 12     24  penalt_mark1  [7.6, 10.4]  penalt_mark   frente       meio
# 13     25  penalt_mark2  [2.8, 10.4]  penalt_mark    atrás       meio
#
#     propabilidade
# 0        0.192430
# 1        0.192430
# 2        0.055793
# 3        0.055793
# 4        0.045649
# 5        0.157443
# 6        0.013236
# 7        0.013236
# 8        0.318702
# 9        0.318702
# 10       0.011803
# 11       0.011803
# 12       0.312328
# 13       0.255541

# %%
lista.sort_values(["propabilidade"], ascending=False)
# Out:
#     index           tag          pos      classes vertical horizontal  \
# 8      12     base_gol1   [9.7, 2.4]     base_gol   frente        esq
# 9      13     base_gol2   [9.7, 5.0]     base_gol   frente        dir
# 12     24  penalt_mark1  [7.6, 10.4]  penalt_mark   frente       meio
# 13     25  penalt_mark2  [2.8, 10.4]  penalt_mark    atrás       meio
# 0       4            L1   [9.7, 0.7]            L   frente        esq
# 1       5            L2   [8.7, 1.2]            L   frente        esq
# 5       9            L6   [0.7, 0.7]            L    atrás        esq
# 2       6            L3   [8.7, 6.2]            L   frente        dir
# 3       7            L4   [9.7, 6.7]            L   frente        dir
# 4       8            L5   [1.7, 1.2]            L    atrás        esq
# 6      10            L7   [0.7, 6.7]            L    atrás        dir
# 7      11            L8   [1.7, 6.2]            L    atrás        dir
# 10     14     base_gol3   [0.7, 2.4]     base_gol    atrás        esq
# 11     15     base_gol4   [0.7, 5.0]     base_gol    atrás        dir
#
#     propabilidade
# 8        0.318702
# 9        0.318702
# 12       0.312328
# 13       0.255541
# 0        0.192430
# 1        0.192430
# 5        0.157443
# 2        0.055793
# 3        0.055793
# 4        0.045649
# 6        0.013236
# 7        0.013236
# 10       0.011803
# 11       0.011803
